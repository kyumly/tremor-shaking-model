# %% [markdown]
# # 데이터 검증

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Dataset.csv")

# %%
X_tarin, X_valid = train_test_split(data, test_size=0.2, random_state=42)

# %%
label = data['Result']
# 손떨림 없음
mask_1= (data['Result']  == 0)

# 손떨림 있음
mask_2= (data['Result'] == 1)

# data = data.drop("Result", axis=1)

# %%
info = data.describe()
info
# Out:
#                  aX            aY            aZ            gX            gY  \
# count  27995.000000  27995.000000  27995.000000  27995.000000  27995.000000
# mean      54.174960   5756.362779 -13338.659904   5002.228684   -239.641400
# std     5220.775301   5201.669402   3059.030305    485.190460    999.942236
# min    -9488.000000  -3148.000000 -19600.000000   3840.000000 -12023.000000
# 25%    -5332.000000    776.000000 -16260.000000   4608.000000   -752.000000
# 50%     1004.000000   4144.000000 -14248.000000   4848.000000      1.000000
# 75%     3724.000000  11524.000000 -11120.000000   5360.000000     77.000000
# max    17788.000000  16288.000000  -2232.000000   6080.000000  11482.000000
#
#                  gZ            mX       mY       mZ        Result
# count  27995.000000  27995.000000  27995.0  27995.0  27995.000000
# mean     275.450938     49.089337     -1.0     -1.0      0.544597
# std     3340.619622   1076.140134      0.0      0.0      0.498016
# min   -32768.000000 -15756.000000     -1.0     -1.0      0.000000
# 25%       75.000000    -56.000000     -1.0     -1.0      0.000000
# 50%      318.000000     11.000000     -1.0     -1.0      1.000000
# 75%      421.000000    189.000000     -1.0     -1.0      1.000000
# max    32767.000000  11103.000000     -1.0     -1.0      1.000000

# %% [markdown]
# # 데이터 전처리

# %%
from sklearn.preprocessing import StandardScaler

st = StandardScaler()

# %%
st_data = st.fit(data).transform(data)

# %%
print(st_data.shape)
st_data : pd.DataFrame
# Out:
# (27995, 10)

# %% [markdown]
# # 모든 데이터 histogram

# %%
data_col = data.columns
print(data_col)
# Out:
# Index(['aX', 'aY', 'aZ', 'gX', 'gY', 'gZ', 'mX', 'mY', 'mZ', 'Result'], dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np

# 3 by 3 그래프를 위한 데이터 생성
# 3 by 3 서브플롯 그리기

fig, axs = plt.subplots(3, 3, figsize=(15, 15))

# 각 서브플롯에 히스토그램 그리기
for i, ax in enumerate(axs.flat):
    data_set = data[data_col[i]]
    ax.hist(data_set, bins=30, color='skyblue', edgecolor='black')
    ax.set_title(f'Data Set {data_col[i]}')
    ax.set_xlabel('Value')
    ax.set_ylabel('count')

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# # 데이터가 흘들렸을때 분산

# %%
import matplotlib.pyplot as plt
import numpy as np

# 3 by 3 그래프를 위한 데이터 생성
# 3 by 3 서브플롯 그리기

fig, axs = plt.subplots(3, 3, figsize=(15, 15))

# 각 서브플롯에 히스토그램 그리기
for i, ax in enumerate(axs.flat):
    data_set = data.loc[mask_2, data_col[i]]
    ax.hist(data_set, bins=30, color='skyblue', edgecolor='black')
    ax.set_title(f'Data Set {data_col[i]}')
    ax.set_xlabel('Value')
    ax.set_ylabel('count')

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %% [markdown]
# # 안떨리는 데이터 분산

# %%
import matplotlib.pyplot as plt
import numpy as np

# 3 by 3 그래프를 위한 데이터 생성
# 3 by 3 서브플롯 그리기

fig, axs = plt.subplots(3, 3, figsize=(15, 15))

print(data.loc[mask_1].shape)
# 각 서브플롯에 히스토그램 그리기
for i, ax in enumerate(axs.flat):
    data_set = data.loc[mask_1, data_col[i]]
    
    ax.hist(data_set, bins=30, color='skyblue', edgecolor='black')
    ax.set_title(f'Data Set {data_col[i]}')
    ax.set_xlabel('Value')
    ax.set_ylabel('count')

# 레이아웃 조정
plt.tight_layout()
plt.show()
# Out:
# (12749, 10)

# %% [markdown]
# # data drop

# %%
X_tarin, X_valid = train_test_split(data, test_size=0.2, random_state=42)

# %%
data = data.drop(['mY', 'mZ', "Result"], axis=1)

# %% [markdown]
# # data boxplot 이상치 값 판단

# %%
print(data)
# Out:
#          aX     aY     aZ    gX    gY    gZ    mX
# 0     -2544  14340  -6864  3840  -335 -1518 -1760
# 1     -2380  14188  -5644  3888  1635 -9604 -2419
# 2      -524  14480  -7148  3888 -1663 -1491   311
# 3      -528  15052  -6672  3904   461 -4012 -1424
# 4     -2808  14040  -5936  3904   595  -339    13
# ...     ...    ...    ...   ...   ...   ...   ...
# 27990 -5208   1152 -15040  6016    23   382   -63
# 27991 -5104   1048 -15160  6016    81   346   -88
# 27992 -5144   1108 -15100  6016     4   362   -32
# 27993 -5052   1892 -14688  6064   413   778   594
# 27994 -5072   1060 -15048  6080   -40   470   -69
#
# [27995 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print(sns.boxplot(data['aX']))
# print(f"이상치 보다 높은 갯수 : {train_seoul.loc[train_seoul.log_price < 11.5].shape[0]}")
# print(f"이상치 보다 낮은 갯수 : {train_seoul.loc[train_seoul.log_price < 9].shape[0]}")
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
data
# Out:
#          aX     aY     aZ    gX    gY    gZ    mX
# 0     -2544  14340  -6864  3840  -335 -1518 -1760
# 1     -2380  14188  -5644  3888  1635 -9604 -2419
# 2      -524  14480  -7148  3888 -1663 -1491   311
# 3      -528  15052  -6672  3904   461 -4012 -1424
# 4     -2808  14040  -5936  3904   595  -339    13
# ...     ...    ...    ...   ...   ...   ...   ...
# 27990 -5208   1152 -15040  6016    23   382   -63
# 27991 -5104   1048 -15160  6016    81   346   -88
# 27992 -5144   1108 -15100  6016     4   362   -32
# 27993 -5052   1892 -14688  6064   413   778   594
# 27994 -5072   1060 -15048  6080   -40   470   -69
#
# [27995 rows x 7 columns]

# %%
data.isna
# Out:
# <bound method DataFrame.isna of          aX     aY     aZ    gX    gY    gZ    mX
# 0     -2544  14340  -6864  3840  -335 -1518 -1760
# 1     -2380  14188  -5644  3888  1635 -9604 -2419
# 2      -524  14480  -7148  3888 -1663 -1491   311
# 3      -528  15052  -6672  3904   461 -4012 -1424
# 4     -2808  14040  -5936  3904   595  -339    13
# ...     ...    ...    ...   ...   ...   ...   ...
# 27990 -5208   1152 -15040  6016    23   382   -63
# 27991 -5104   1048 -15160  6016    81   346   -88
# 27992 -5144   1108 -15100  6016     4   362   -32
# 27993 -5052   1892 -14688  6064   413   778   594
# 27994 -5072   1060 -15048  6080   -40   470   -69
#
# [27995 rows x 7 columns]>

# %% [markdown]
# # 각가에 데이터 전처리

# %%
data.shape
# Out:
# (27995, 7)

# %%
shacking_off= data[mask_1]
shacking_on = data[mask_2]

# %% [markdown]
# # modeling

# %%
X_tarin, X_valid = train_test_split(data, test_size=0.2, random_state=42)
# data = data.drop(['mY', 'mZ', "Result"], axis=1)
X_train_label = X_tarin['Result']
X_valid_label = X_valid['Result']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Result'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 X_tarin, X_valid = train_test_split(data, test_size=0.2, random_state=42)
#       2 # data = data.drop(['mY', 'mZ', "Result"], axis=1)
# ----> 3 X_train_label = X_tarin['Result']
#       4 X_valid_label = X_valid['Result']
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Result'

# %%
X_tarin = X_tarin.drop(['mY', 'mZ', "Result"], axis=1)
X_valid = X_valid.drop(['mY', 'mZ', "Result"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 X_tarin = X_tarin.drop(['mY', 'mZ', "Result"], axis=1)
#       2 X_valid = X_valid.drop(['mY', 'mZ', "Result"], axis=1)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['mY', 'mZ', 'Result'] not found in axis"

# %%
shacking_off_ax = shacking_off['aX']
shacking_on_ax = shacking_on['aX']
print()
plt.scatter(range(len(shacking_off_ax)), shacking_off_ax, color='red')
plt.scatter(range(len(shacking_on_ax)), shacking_on_ax, color='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 shacking_off_ax = shacking_off['aX']
#       2 shacking_on_ax = shacking_on['aX']
#       3 print()
#
# NameError: name 'shacking_off' is not defined

# %% [markdown]
# # Modeling

# %%
from sklearn.preprocessing import StandardScaler

st = StandardScaler()
st_data = st.fit(data).transform(data)

# %%
st_data
# Out:
# array([[-0.49766964,  1.65019917,  2.11661046, ..., -0.09536581,
#         -0.53687135, -1.68112088],
#        [-0.46625612,  1.62097726,  2.51543678, ...,  1.87478318,
#         -2.95742363, -2.2935056 ],
#        [-0.11074702,  1.67711409,  2.02376893, ..., -1.42346625,
#         -0.52878887,  0.24338405],
#        ...,
#        [-0.99568886, -0.89364499, -0.57579408, ...,  0.24365983,
#          0.02590855, -0.07535337],
#        [-0.97806664, -0.74292145, -0.44110848, ...,  0.65269076,
#          0.15043857,  0.50636565],
#        [-0.98189756, -0.90287296, -0.55879493, ...,  0.1996565 ,
#          0.05823846, -0.10973612]])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(data.shape)
print(label.shape)
# Out:
# (27995, 7)
# (27995,)

# %%
np_label =np.array(label)

class CustomDataset(Dataset):
    def __init__(self, data, label):
        self.data = data
        self.label = label
        
    def __len__(self):
        return len(self.data)
    
    
    def __getitem__(self, item):
        return self.data[item], self.label[item]

# %%
dataset = CustomDataset(st_data, np_label)

# %%
data_loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
class CustomModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(in_features=7, out_features=256, dtype=torch.float64)
        self.fc2 = nn.Linear(in_features=256, out_features=256, dtype=torch.float64)
        self.fc3 = nn.Linear(in_features=256, out_features=64, dtype=torch.float64)
        self.fc4 = nn.Linear(in_features=64, out_features=32, dtype=torch.float64)
        self.fc5 = nn.Linear(in_features=32, out_features=1, dtype=torch.float64)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
model = CustomModel()

# %%
small, label = next(iter(data_loader))

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-7)
criterion = nn.BCELoss()

# %%
model.to(device)
criterion.to(device)
# Out:
# BCELoss()

# %%
from tqdm import tqdm

model.train()
losses = 0
loss_list= []
for epoch in range(5):
    for d, v in tqdm(data_loader):
        
        data = d.to(device)
        v = v.to(device)
        optimizer.zero_grad()
        
        output_data = model(data) 
        result = F.sigmoid(output_data)
        loss = criterion(result.reshape(-1, 1).to(torch.float32), v.reshape(-1, 1).to(torch.float32))
        loss_list.append(loss.item())
        loss.backward()
        optimizer.step()
        losses += loss.item()    
    
print(losses/len(data_loader))
# Out:
# 100%|██████████| 438/438 [00:01<00:00, 402.03it/s]
# 100%|██████████| 438/438 [00:00<00:00, 488.21it/s]
# 100%|██████████| 438/438 [00:00<00:00, 475.84it/s]
# 100%|██████████| 438/438 [00:00<00:00, 477.62it/s]
# 100%|██████████| 438/438 [00:00<00:00, 480.25it/s]
# 0.09954229548648447

# %%
epochs = range(1, len(loss_list) + 1)

# Plot the loss values
plt.plot(epochs, loss_list, 'b', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
epoch_loss = 0
epoch_acc = 0
model.eval()
loss_history = []

with torch.no_grad():
    for i, (d, v) in enumerate(data_loader):
        data = d.to(device)
        v = v.to(device)
        output_data = model(data)
        result = F.sigmoid(output_data)
        rounded_preds = torch.round(result)
        correct = (rounded_preds.flatten() == v)
        accuracy = correct.sum() / len(correct)
        print(f"{i}정확도 : {accuracy*100}%")
        loss = criterion(result.reshape(-1, 1).to(torch.float32), v.reshape(-1, 1).to(torch.float32))
        loss_history.append(loss.item())
        epoch_loss += loss.item()
# Out:
# 0정확도 : 100.0%
# 1정확도 : 100.0%
# 2정확도 : 98.4375%
# 3정확도 : 100.0%
# 4정확도 : 100.0%
# 5정확도 : 100.0%
# 6정확도 : 100.0%
# 7정확도 : 98.4375%
# 8정확도 : 100.0%
# 9정확도 : 96.875%
# 10정확도 : 98.4375%
# 11정확도 : 100.0%
# 12정확도 : 100.0%
# 13정확도 : 98.4375%
# 14정확도 : 100.0%
# 15정확도 : 100.0%
# 16정확도 : 98.4375%
# 17정확도 : 98.4375%
# 18정확도 : 100.0%
# 19정확도 : 100.0%
# 20정확도 : 100.0%
# 21정확도 : 100.0%
# 22정확도 : 98.4375%
# 23정확도 : 100.0%
# 24정확도 : 98.4375%
# 25정확도 : 100.0%
# 26정확도 : 100.0%
# 27정확도 : 100.0%
# 28정확도 : 100.0%
# 29정확도 : 100.0%
# 30정확도 : 98.4375%
# 31정확도 : 100.0%
# 32정확도 : 100.0%
# 33정확도 : 100.0%
# 34정확도 : 100.0%
# 35정확도 : 100.0%
# 36정확도 : 98.4375%
# 37정확도 : 100.0%
# 38정확도 : 98.4375%
# 39정확도 : 98.4375%
# 40정확도 : 100.0%
# 41정확도 : 96.875%
# 42정확도 : 100.0%
# 43정확도 : 100.0%
# 44정확도 : 100.0%
# 45정확도 : 100.0%
# 46정확도 : 98.4375%
# 47정확도 : 100.0%
# 48정확도 : 100.0%
# 49정확도 : 100.0%
# 50정확도 : 100.0%
# 51정확도 : 100.0%
# 52정확도 : 100.0%
# 53정확도 : 100.0%
# 54정확도 : 100.0%
# 55정확도 : 100.0%
# 56정확도 : 98.4375%
# 57정확도 : 100.0%
# 58정확도 : 100.0%
# 59정확도 : 98.4375%
# 60정확도 : 100.0%
# 61정확도 : 100.0%
# 62정확도 : 100.0%
# 63정확도 : 96.875%
# 64정확도 : 100.0%
# 65정확도 : 100.0%
# 66정확도 : 96.875%
# 67정확도 : 100.0%
# 68정확도 : 100.0%
# 69정확도 : 100.0%
# 70정확도 : 100.0%
# 71정확도 : 100.0%
# 72정확도 : 98.4375%
# 73정확도 : 98.4375%
# 74정확도 : 100.0%
# 75정확도 : 100.0%
# 76정확도 : 100.0%
# 77정확도 : 100.0%
# 78정확도 : 98.4375%
# 79정확도 : 96.875%
# 80정확도 : 100.0%
# 81정확도 : 100.0%
# 82정확도 : 100.0%
# 83정확도 : 100.0%
# 84정확도 : 100.0%
# 85정확도 : 98.4375%
# 86정확도 : 100.0%
# 87정확도 : 100.0%
# 88정확도 : 100.0%
# 89정확도 : 100.0%
# 90정확도 : 100.0%
# 91정확도 : 100.0%
# 92정확도 : 100.0%
# 93정확도 : 100.0%
# 94정확도 : 98.4375%
# 95정확도 : 100.0%
# 96정확도 : 98.4375%
# 97정확도 : 100.0%
# 98정확도 : 98.4375%
# 99정확도 : 100.0%
# 100정확도 : 100.0%
# 101정확도 : 100.0%
# 102정확도 : 100.0%
# 103정확도 : 100.0%
# 104정확도 : 100.0%
# 105정확도 : 100.0%
# 106정확도 : 100.0%
# 107정확도 : 100.0%
# 108정확도 : 100.0%
# 109정확도 : 98.4375%
# 110정확도 : 98.4375%
# 111정확도 : 100.0%
# 112정확도 : 98.4375%
# 113정확도 : 100.0%
# 114정확도 : 96.875%
# 115정확도 : 96.875%
# 116정확도 : 100.0%
# 117정확도 : 98.4375%
# 118정확도 : 98.4375%
# 119정확도 : 98.4375%
# 120정확도 : 100.0%
# 121정확도 : 100.0%
# 122정확도 : 100.0%
# 123정확도 : 100.0%
# 124정확도 : 100.0%
# 125정확도 : 100.0%
# 126정확도 : 98.4375%
# 127정확도 : 100.0%
# 128정확도 : 100.0%
# 129정확도 : 100.0%
# 130정확도 : 100.0%
# 131정확도 : 98.4375%
# 132정확도 : 100.0%
# 133정확도 : 100.0%
# 134정확도 : 100.0%
# 135정확도 : 100.0%
# 136정확도 : 100.0%
# 137정확도 : 100.0%
# 138정확도 : 100.0%
# 139정확도 : 100.0%
# 140정확도 : 100.0%
# 141정확도 : 100.0%
# 142정확도 : 100.0%
# 143정확도 : 100.0%
# 144정확도 : 100.0%
# 145정확도 : 100.0%
# 146정확도 : 98.4375%
# 147정확도 : 100.0%
# 148정확도 : 100.0%
# 149정확도 : 100.0%
# 150정확도 : 100.0%
# 151정확도 : 100.0%
# 152정확도 : 100.0%
# 153정확도 : 98.4375%
# 154정확도 : 100.0%
# 155정확도 : 100.0%
# 156정확도 : 100.0%
# 157정확도 : 100.0%
# 158정확도 : 100.0%
# 159정확도 : 98.4375%
# 160정확도 : 100.0%
# 161정확도 : 100.0%
# 162정확도 : 100.0%
# 163정확도 : 100.0%
# 164정확도 : 100.0%
# 165정확도 : 100.0%
# 166정확도 : 96.875%
# 167정확도 : 100.0%
# 168정확도 : 100.0%
# 169정확도 : 100.0%
# 170정확도 : 100.0%
# 171정확도 : 98.4375%
# 172정확도 : 100.0%
# 173정확도 : 96.875%
# 174정확도 : 100.0%
# 175정확도 : 100.0%
# 176정확도 : 100.0%
# 177정확도 : 100.0%
# 178정확도 : 98.4375%
# 179정확도 : 98.4375%
# 180정확도 : 100.0%
# 181정확도 : 100.0%
# 182정확도 : 100.0%
# 183정확도 : 98.4375%
# 184정확도 : 100.0%
# 185정확도 : 100.0%
# 186정확도 : 98.4375%
# 187정확도 : 100.0%
# 188정확도 : 98.4375%
# 189정확도 : 98.4375%
# 190정확도 : 100.0%
# 191정확도 : 100.0%
# 192정확도 : 100.0%
# 193정확도 : 96.875%
# 194정확도 : 100.0%
# 195정확도 : 100.0%
# 196정확도 : 100.0%
# 197정확도 : 100.0%
# 198정확도 : 100.0%
# 199정확도 : 100.0%
# 200정확도 : 100.0%
# 201정확도 : 100.0%
# 202정확도 : 100.0%
# 203정확도 : 100.0%
# 204정확도 : 100.0%
# 205정확도 : 98.4375%
# 206정확도 : 98.4375%
# 207정확도 : 100.0%
# 208정확도 : 100.0%
# 209정확도 : 98.4375%
# 210정확도 : 100.0%
# 211정확도 : 100.0%
# 212정확도 : 100.0%
# 213정확도 : 100.0%
# 214정확도 : 100.0%
# 215정확도 : 100.0%
# 216정확도 : 100.0%
# 217정확도 : 98.4375%
# 218정확도 : 100.0%
# 219정확도 : 98.4375%
# 220정확도 : 100.0%
# 221정확도 : 96.875%
# 222정확도 : 98.4375%
# 223정확도 : 100.0%
# 224정확도 : 100.0%
# 225정확도 : 96.875%
# 226정확도 : 100.0%
# 227정확도 : 100.0%
# 228정확도 : 100.0%
# 229정확도 : 100.0%
# 230정확도 : 100.0%
# 231정확도 : 98.4375%
# 232정확도 : 98.4375%
# 233정확도 : 100.0%
# 234정확도 : 96.875%
# 235정확도 : 100.0%
# 236정확도 : 96.875%
# 237정확도 : 100.0%
# 238정확도 : 98.4375%
# 239정확도 : 100.0%
# 240정확도 : 100.0%
# 241정확도 : 96.875%
# 242정확도 : 100.0%
# 243정확도 : 98.4375%
# 244정확도 : 100.0%
# 245정확도 : 100.0%
# 246정확도 : 100.0%
# 247정확도 : 100.0%
# 248정확도 : 98.4375%
# 249정확도 : 100.0%
# 250정확도 : 100.0%
# 251정확도 : 98.4375%
# 252정확도 : 98.4375%
# 253정확도 : 96.875%
# 254정확도 : 100.0%
# 255정확도 : 98.4375%
# 256정확도 : 100.0%
# 257정확도 : 100.0%
# 258정확도 : 96.875%
# 259정확도 : 100.0%
# 260정확도 : 98.4375%
# 261정확도 : 100.0%
# 262정확도 : 100.0%
# 263정확도 : 100.0%
# 264정확도 : 100.0%
# 265정확도 : 100.0%
# 266정확도 : 100.0%
# 267정확도 : 98.4375%
# 268정확도 : 100.0%
# 269정확도 : 98.4375%
# 270정확도 : 100.0%
# 271정확도 : 98.4375%
# 272정확도 : 98.4375%
# 273정확도 : 100.0%
# 274정확도 : 100.0%
# 275정확도 : 100.0%
# 276정확도 : 100.0%
# 277정확도 : 98.4375%
# 278정확도 : 100.0%
# 279정확도 : 98.4375%
# 280정확도 : 100.0%
# 281정확도 : 100.0%
# 282정확도 : 98.4375%
# 283정확도 : 98.4375%
# 284정확도 : 100.0%
# 285정확도 : 100.0%
# 286정확도 : 100.0%
# 287정확도 : 100.0%
# 288정확도 : 100.0%
# 289정확도 : 95.3125%
# 290정확도 : 100.0%
# 291정확도 : 100.0%
# 292정확도 : 96.875%
# 293정확도 : 98.4375%
# 294정확도 : 98.4375%
# 295정확도 : 100.0%
# 296정확도 : 100.0%
# 297정확도 : 100.0%
# 298정확도 : 100.0%
# 299정확도 : 100.0%
# 300정확도 : 100.0%
# 301정확도 : 100.0%
# 302정확도 : 100.0%
# 303정확도 : 96.875%
# 304정확도 : 100.0%
# 305정확도 : 100.0%
# 306정확도 : 100.0%
# 307정확도 : 100.0%
# 308정확도 : 100.0%
# 309정확도 : 100.0%
# 310정확도 : 100.0%
# 311정확도 : 100.0%
# 312정확도 : 100.0%
# 313정확도 : 98.4375%
# 314정확도 : 100.0%
# 315정확도 : 100.0%
# 316정확도 : 100.0%
# 317정확도 : 100.0%
# 318정확도 : 100.0%
# 319정확도 : 100.0%
# 320정확도 : 100.0%
# 321정확도 : 98.4375%
# 322정확도 : 100.0%
# 323정확도 : 100.0%
# 324정확도 : 100.0%
# 325정확도 : 100.0%
# 326정확도 : 100.0%
# 327정확도 : 100.0%
# 328정확도 : 98.4375%
# 329정확도 : 100.0%
# 330정확도 : 98.4375%
# 331정확도 : 100.0%
# 332정확도 : 98.4375%
# 333정확도 : 98.4375%
# 334정확도 : 100.0%
# 335정확도 : 100.0%
# 336정확도 : 98.4375%
# 337정확도 : 96.875%
# 338정확도 : 100.0%
# 339정확도 : 98.4375%
# 340정확도 : 100.0%
# 341정확도 : 98.4375%
# 342정확도 : 100.0%
# 343정확도 : 100.0%
# 344정확도 : 98.4375%
# 345정확도 : 100.0%
# 346정확도 : 100.0%
# 347정확도 : 98.4375%
# 348정확도 : 98.4375%
# 349정확도 : 96.875%
# 350정확도 : 100.0%
# 351정확도 : 100.0%
# 352정확도 : 100.0%
# 353정확도 : 100.0%
# 354정확도 : 96.875%
# 355정확도 : 100.0%
# 356정확도 : 100.0%
# 357정확도 : 100.0%
# 358정확도 : 100.0%
# 359정확도 : 100.0%
# 360정확도 : 100.0%
# 361정확도 : 100.0%
# 362정확도 : 98.4375%
# 363정확도 : 98.4375%
# 364정확도 : 100.0%
# 365정확도 : 100.0%
# 366정확도 : 98.4375%
# 367정확도 : 100.0%
# 368정확도 : 100.0%
# 369정확도 : 100.0%
# 370정확도 : 100.0%
# 371정확도 : 100.0%
# 372정확도 : 98.4375%
# 373정확도 : 100.0%
# 374정확도 : 98.4375%
# 375정확도 : 100.0%
# 376정확도 : 98.4375%
# 377정확도 : 98.4375%
# 378정확도 : 96.875%
# 379정확도 : 100.0%
# 380정확도 : 96.875%
# 381정확도 : 100.0%
# 382정확도 : 96.875%
# 383정확도 : 100.0%
# 384정확도 : 100.0%
# 385정확도 : 98.4375%
# 386정확도 : 96.875%
# 387정확도 : 100.0%
# 388정확도 : 100.0%
# 389정확도 : 100.0%
# 390정확도 : 100.0%
# 391정확도 : 98.4375%
# 392정확도 : 98.4375%
# 393정확도 : 100.0%
# 394정확도 : 100.0%
# 395정확도 : 100.0%
# 396정확도 : 100.0%
# 397정확도 : 100.0%
# 398정확도 : 98.4375%
# 399정확도 : 100.0%
# 400정확도 : 100.0%
# 401정확도 : 100.0%
# 402정확도 : 100.0%
# 403정확도 : 100.0%
# 404정확도 : 100.0%
# 405정확도 : 100.0%
# 406정확도 : 100.0%
# 407정확도 : 100.0%
# 408정확도 : 96.875%
# 409정확도 : 100.0%
# 410정확도 : 100.0%
# 411정확도 : 100.0%
# 412정확도 : 100.0%
# 413정확도 : 98.4375%
# 414정확도 : 100.0%
# 415정확도 : 100.0%
# 416정확도 : 100.0%
# 417정확도 : 100.0%
# 418정확도 : 100.0%
# 419정확도 : 100.0%
# 420정확도 : 100.0%
# 421정확도 : 100.0%
# 422정확도 : 98.4375%
# 423정확도 : 100.0%
# 424정확도 : 100.0%
# 425정확도 : 100.0%
# 426정확도 : 98.4375%
# 427정확도 : 100.0%
# 428정확도 : 100.0%
# 429정확도 : 98.4375%
# 430정확도 : 100.0%
# 431정확도 : 100.0%
# 432정확도 : 100.0%
# 433정확도 : 98.4375%
# 434정확도 : 100.0%
# 435정확도 : 100.0%
# 436정확도 : 100.0%
# 437정확도 : 100.0%

# %%
loss_history
# Out:
# [0.012691943906247616,
#  0.016388848423957825,
#  0.011871914379298687,
#  0.05402331426739693,
#  0.006215719971805811,
#  0.010243234224617481,
#  0.01072913408279419,
#  0.04200511425733566,
#  0.16617117822170258,
#  0.04305777698755264,
#  0.007337520364671946,
#  0.0049842181615531445,
#  0.06010410562157631,
#  0.01944817043840885,
#  0.02198953740298748,
#  0.001582388300448656,
#  0.0038102134130895138,
#  0.00791183952242136,
#  0.004082198720425367,
#  0.0013791965320706367,
#  0.02191455475986004,
#  0.011784596368670464,
#  0.026231976225972176,
#  0.009595442563295364,
#  0.011107651516795158,
#  0.006557060871273279,
#  0.0516170859336853,
#  0.05915055796504021,
#  0.015591567382216454,
#  0.11503634601831436,
#  0.1181953102350235,
#  0.01577943190932274,
#  0.022530118003487587,
#  0.0019501468632370234,
#  0.049544014036655426,
#  0.023008005693554878,
#  0.03289687633514404,
#  0.0037429453805088997,
#  0.0010916553437709808,
#  0.0029890260193496943,
#  0.00900940876454115,
#  0.029411206021904945,
#  0.005105392076075077,
#  0.01465789508074522,
#  0.03975624218583107,
#  0.0019270975608378649,
#  0.0018090492812916636,
#  0.036054838448762894,
#  0.05713438615202904,
#  0.0034029576927423477,
#  0.004339778330177069,
#  0.00223480979911983,
#  0.02648768201470375,
#  0.05007091909646988,
#  0.027793414890766144,
#  0.005631405394524336,
#  0.00500712962821126,
#  0.01882437989115715,
#  0.020104683935642242,
#  0.0036560813896358013,
#  0.0028304236475378275,
#  0.04611323028802872,
#  0.0924106314778328,
#  0.0016220032703131437,
#  0.0010008604731410742,
#  0.0064208293333649635,
#  0.08708284795284271,
#  0.0015304452972486615,
#  0.06670069694519043,
#  0.025459902361035347,
#  0.10027876496315002,
#  0.012112913653254509,
#  0.05088294297456741,
#  0.029309067875146866,
#  0.0028248336166143417,
#  0.002168544102460146,
#  0.07890241593122482,
#  0.01930169202387333,
#  0.0033569035585969687,
#  0.003202304244041443,
#  0.004307101480662823,
#  0.007600046694278717,
#  0.006242353469133377,
#  0.06509023904800415,
#  0.004065561108291149,
#  0.005208434071391821,
#  0.02325226552784443,
#  0.00318169710226357,
#  0.002581855282187462,
#  0.0062281908467411995,
#  0.009455671533942223,
#  0.008438879624009132,
#  0.0031094769947230816,
#  0.014784133993089199,
#  0.01259674597531557,
#  0.007430792320519686,
#  0.0009852477815002203,
#  0.0839291512966156,
#  0.0036203269846737385,
#  0.005274256691336632,
#  0.05021897703409195,
#  0.007334433495998383,
#  0.005077430047094822,
#  0.0047371163964271545,
#  0.05582498013973236,
#  0.004203219432383776,
#  0.0960984081029892,
#  0.023384353145956993,
#  0.016653962433338165,
#  0.0012435952667146921,
#  0.028156127780675888,
#  0.026954811066389084,
#  0.0016424722271040082,
#  0.026028893887996674,
#  0.0020860789809376,
#  0.08544008433818817,
#  0.009474080055952072,
#  0.043522659689188004,
#  0.1037987768650055,
#  0.004141658544540405,
#  0.003197069512680173,
#  0.042505573481321335,
#  0.07737411558628082,
#  0.004721056204289198,
#  0.0021101145539432764,
#  0.05316167324781418,
#  0.005495586432516575,
#  0.13613563776016235,
#  0.0351933091878891,
#  0.01603689044713974,
#  0.09742376208305359,
#  0.03427491709589958,
#  0.024951579049229622,
#  0.061540037393569946,
#  0.012743014842271805,
#  0.06517813354730606,
#  0.012967490591108799,
#  0.06336987763643265,
#  0.0026294542476534843,
#  0.0010428405366837978,
#  0.1172408014535904,
#  0.006144531071186066,
#  0.0044046733528375626,
#  0.007583131082355976,
#  0.06437712907791138,
#  0.0024050583597272635,
#  0.009061155840754509,
#  0.0014019589871168137,
#  0.013803403824567795,
#  0.0076781827956438065,
#  0.01914406009018421,
#  0.02092168480157852,
#  0.024426858872175217,
#  0.13605238497257233,
#  0.036401353776454926,
#  0.05370890349149704,
#  0.02529984340071678,
#  0.02967551350593567,
#  0.01030123420059681,
#  0.027497755363583565,
#  0.0012435164535418153,
#  0.011885711923241615,
#  0.0054281335324049,
#  0.0016074266750365496,
#  0.058302100747823715,
#  0.054043181240558624,
#  0.0017919217934831977,
#  0.0007171942852437496,
#  0.02211838774383068,
#  0.003405568655580282,
#  0.0030304761603474617,
#  0.006099098362028599,
#  0.0025297035463154316,
#  0.008039189502596855,
#  0.004040544852614403,
#  0.0018237822223454714,
#  0.035275280475616455,
#  0.01876174844801426,
#  0.0167776420712471,
#  0.005495580844581127,
#  0.036907635629177094,
#  0.008336750790476799,
#  0.08376799523830414,
#  0.0013623381964862347,
#  0.0014206403866410255,
#  0.0076754288747906685,
#  0.011706152930855751,
#  0.0038566202856600285,
#  0.0009008804336190224,
#  0.02727191150188446,
#  0.013430177234113216,
#  0.0671880915760994,
#  0.030120618641376495,
#  0.03376958891749382,
#  0.037978991866111755,
#  0.013391832821071148,
#  0.06816660612821579,
#  0.0636177584528923,
#  0.010336712002754211,
#  0.019945265725255013,
#  0.06630754470825195,
#  0.0028452493716031313,
#  0.006595492362976074,
#  0.0024313137400895357,
#  0.0017880673985928297,
#  0.05249243602156639,
#  0.011477484367787838,
#  0.011657940223813057,
#  0.009198369458317757,
#  0.016665278002619743,
#  0.006121473386883736,
#  0.0030502190347760916,
#  0.0009640929056331515,
#  0.010222727432847023,
#  0.08557198196649551,
#  0.00911317951977253,
#  0.0014389363350346684,
#  0.01044546626508236,
#  0.025098303332924843,
#  0.006874880753457546,
#  0.02036328986287117,
#  0.002255867002531886,
#  0.0006618860643357038,
#  0.01168196089565754,
#  0.006843410432338715,
#  0.0016836976865306497,
#  0.0017418910283595324,
#  0.028290797024965286,
#  0.12502434849739075,
#  0.008677375502884388,
#  0.07822635769844055,
#  0.00457895640283823,
#  0.0012551203835755587,
#  0.09370732307434082,
#  0.001444626715965569,
#  0.05058418959379196,
#  0.002612609649077058,
#  0.002436126582324505,
#  0.024177685379981995,
#  0.0016970199067145586,
#  0.03937248885631561,
#  0.06052878126502037,
#  0.006430394947528839,
#  0.002028523711487651,
#  0.005541075486689806,
#  0.08770458400249481,
#  0.0037369639612734318,
#  0.0007410213584080338,
#  0.14307117462158203,
#  0.022584836930036545,
#  0.005861345678567886,
#  0.005702464375644922,
#  0.0028888541273772717,
#  0.0026418359484523535,
#  0.0641295537352562,
#  0.008711121045053005,
#  0.019823268055915833,
#  0.008221994154155254,
#  0.003024936653673649,
#  0.027752304449677467,
#  0.009543275460600853,
#  0.03169097378849983,
#  0.007839703001081944,
#  0.020177626982331276,
#  0.041015349328517914,
#  0.007319541648030281,
#  0.09864456951618195,
#  0.004284932278096676,
#  0.009902333840727806,
#  0.07817397266626358,
#  0.024354316294193268,
#  0.028625305742025375,
#  0.011166930198669434,
#  0.010162108577787876,
#  0.0009529474191367626,
#  0.0180835984647274,
#  0.01587715372443199,
#  0.021616481244564056,
#  0.006155712064355612,
#  0.038941673934459686,
#  0.01428954303264618,
#  0.004075158387422562,
#  0.03690267726778984,
#  0.011996185407042503,
#  0.003937487490475178,
#  0.002715339418500662,
#  0.08140706270933151,
#  0.0026141167618334293,
#  0.0011665044585242867,
#  0.012201660312712193,
#  0.05427689850330353,
#  0.05001627281308174,
#  0.07945018261671066,
#  0.007269746158272028,
#  0.03027189150452614,
#  0.0018560659373179078,
#  0.008567296899855137,
#  0.0018253290327265859,
#  0.0019356714328750968,
#  0.01477765291929245,
#  0.001710829557850957,
#  0.00514946086332202,
#  0.013043062761425972,
#  0.0019736867398023605,
#  0.003357021836563945,
#  0.0030433908104896545,
#  0.0015532966936007142,
#  0.02189025655388832,
#  0.004749680869281292,
#  0.029249530285596848,
#  0.0029715534765273333,
#  0.035723812878131866,
#  0.06944963335990906,
#  0.013665720820426941,
#  0.05302220582962036,
#  0.057078197598457336,
#  0.004687455017119646,
#  0.002470525912940502,
#  0.012967774644494057,
#  0.0008724938961677253,
#  0.06342491507530212,
#  0.07407639175653458,
#  0.020523084327578545,
#  0.091656893491745,
#  0.03924257680773735,
#  0.004271519370377064,
#  0.0008540056878700852,
#  0.0042047398164868355,
#  0.12783914804458618,
#  0.04120100662112236,
#  0.0012070201337337494,
#  0.0074805463664233685,
#  0.031093327328562737,
#  0.015090947039425373,
#  0.0023556507658213377,
#  0.049709949642419815,
#  0.004548274911940098,
#  0.01721411570906639,
#  0.0017857359489426017,
#  0.004699406214058399,
#  0.010417851619422436,
#  0.01617894135415554,
#  0.0008896841900423169,
#  0.021360352635383606,
#  0.009816182777285576,
#  0.02633684128522873,
#  0.0026077914517372847,
#  0.016738180071115494,
#  0.009570054709911346,
#  0.01436743326485157,
#  0.0060597071424126625,
#  0.01612120494246483,
#  0.0037647217977792025,
#  0.01864268258213997,
#  0.009755716659128666,
#  0.0029401585925370455,
#  0.04386289417743683,
#  0.033222753554582596,
#  0.06088211387395859,
#  0.004302379209548235,
#  0.0025776769034564495,
#  0.015514913946390152,
#  0.0014274902641773224,
#  0.013517623767256737,
#  0.0985349640250206,
#  0.007157733663916588,
#  0.047927889972925186,
#  0.0018935049884021282,
#  0.004675503820180893,
#  0.005180926062166691,
#  0.003146510338410735,
#  0.004884549882262945,
#  0.035317931324243546,
#  0.05978197976946831,
#  0.0018832484493032098,
#  0.0011913024354726076,
#  0.014537062495946884,
#  0.0015216907486319542,
#  0.019782038405537605,
#  0.0016470346599817276,
#  0.048816848546266556,
#  0.03349895402789116,
#  0.07762712240219116,
#  0.0016967891715466976,
#  0.05092616379261017,
#  0.0013393610715866089,
#  0.07708412408828735,
#  0.054459959268569946,
#  0.06111173331737518,
#  0.007895682007074356,
#  0.0042682429775595665,
#  0.006043739151209593,
#  0.1025543287396431,
#  0.06304965168237686,
#  0.0028275607619434595,
#  0.003260295372456312,
#  0.01343386247754097,
#  0.03702285885810852,
#  0.003596711903810501,
#  0.01563735492527485,
#  0.10036365687847137,
#  0.013472439721226692,
#  0.04834567382931709,
#  0.0067478809505701065,
#  0.06935293227434158,
#  0.003085765056312084,
#  0.017227377742528915,
#  0.04410189017653465,
#  0.006452157162129879,
#  0.0016148630529642105,
#  0.00521254725754261,
#  0.04008506238460541,
#  0.0011237405706197023,
#  0.0016376888379454613,
#  0.014833190478384495,
#  0.11310319602489471,
#  0.058470144867897034,
#  0.006344637367874384,
#  0.011918751522898674,
#  0.0028482223860919476,
#  0.004796142224222422,
#  0.002647869288921356,
#  0.0023985726293176413,
#  0.003217384684830904,
#  0.02237347885966301,
#  0.036998022347688675,
#  0.031557291746139526,
#  0.006829884368926287,
#  0.0007935509784147143,
#  0.00372009607963264,
#  0.06464126706123352,
#  0.10099397599697113,
#  0.0026288870722055435,
#  0.001994050806388259,
#  0.0862574502825737,
#  0.02611670456826687,
#  0.014747461304068565,
#  0.0013861029874533415]
